# %%
muTrue = 100
sdTrue = 15

muHyp = 106
n = 9
alpha = 0.05 # The probability of accepting Ha when it does not exist
beta = None # The probability of rejecting Ha effect when it exists
power = 1 - beta # The probability of accepting Ha when it exists
